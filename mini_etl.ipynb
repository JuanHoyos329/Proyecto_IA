# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
files = os.listdir("Datasets")
xlsx_files = [os.path.join("Datasets", f) for f in files if f.endswith('.xlsx')]
df_list = [pd.read_excel(file) for file in xlsx_files]
df = pd.concat(df_list, ignore_index=True)
df.head()
# Out:
#    Campaña  Despacho  Cod. trans    Pedido Zona     Código  Identificación  \
# 0   202407    296461          23  37076500  V02  V02004028        29121278
# 1   202407    296601          23  37087842  601  601004287        26396193
# 2   202407    296601          23  37093297  580  580011140      1112490780
# 3   202407    296621          23  37098642  594  594003236        66940803
# 4   202407    296832          23  37105003  603   60301124        25717466
#
#                        Nombres  \
# 0  PAOLA ANDREA RIVILLAS AMAYA
# 1  CERBELINA MOSQUERA MOSQUERA
# 2      MANUELA RAMIREZ SANCHEZ
# 3      FANERY CORRLES BERMUDES
# 4          MARCIA FLOREZ LOPEZ
#
#                                    Dirección entrega      Telefono  ...  \
# 0  KR 61 18 16 APTO 486 TO V CONJ CANAVERALES 3- ...  0-3165249159  ...
# 1                     KR 47A 48 39- TEL 0-3143423923  0-3143423923  ...
# 2   CR 1H NORTE 77-10 SEGUNDO PISO- TEL 0-3154678944  0-3154678944  ...
# 3               CALLETERSERA SN124- TEL 0-3016931064  0-3016931064  ...
# 4       CL 18 A  9 A 11  PISO NO 1- TEL 0-3136142043  0-3136142043  ...
#
#     Longitud Transportador      Track Novedad             Entregado Anotación  \
# 0 -76.501666        TZY274  ENTREGADO     NaN  TERCERO EN DOMICILIO       NaN
# 1 -76.501645        CBZ922  ENTREGADO     NaN               ASESORA       NaN
# 2 -76.487991        TZY274  ENTREGADO     NaN               ASESORA       NaN
# 3 -76.687145        TZN919  ENTREGADO     NaN               ASESORA       NaN
# 4 -76.531023        CEN356  ENTREGADO     NaN               ASESORA       NaN
#
#   Transportista Tipo Docu Nro visita  Estado.1
# 0    daissydiaz         F          1  A TIEMPO
# 1    daissydiaz         F          1  A TIEMPO
# 2    daissydiaz         F          1  A TIEMPO
# 3    daissydiaz         F          1  A TIEMPO
# 4    daissydiaz         F          1  A TIEMPO
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 55275 entries, 0 to 55274
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Campaña            55275 non-null  int64
#  1   Despacho           55275 non-null  int64
#  2   Cod. trans         55275 non-null  int64
#  3   Pedido             55275 non-null  int64
#  4   Zona               55275 non-null  str
#  5   Código             55275 non-null  str
#  6   Identificación     55275 non-null  int64
#  7   Nombres            55275 non-null  str
#  8   Dirección entrega  55273 non-null  str
#  9   Telefono           55273 non-null  str
#  10  Barrio             55275 non-null  str
#  11  Ciudad             55275 non-null  str
#  12  Fecha pedido       55275 non-null  str
#  13  Fecha facturado    55275 non-null  str
#  14  Hora facturado     55275 non-null  str
#  15  Fecha embalado     55266 non-null  str
#  16  Hora embalado      55266 non-null  str
#  17  Fecha despachado   55266 non-null  str
#  18  Estado             55275 non-null  str
#  19  Dias entregado     55275 non-null  int64
#  20  Cajas              55275 non-null  int64
#  21  Corte              55275 non-null  int64
#  22  Placa vehiculo     55199 non-null  str
#  23  Regional           55275 non-null  str
#  24  Line pick          5096 non-null   str
#  25  Fecha masivo       13193 non-null  object
#  26  Fecha recibo LD    50971 non-null  object
#  27  Fecha reparto      55148 non-null  object
#  28  Fecha entrega      55016 non-null  object
#  29  Latitud            55016 non-null  float64
#  30  Longitud           55016 non-null  float64
#  31  Transportador      55148 non-null  object
#  32  Track              55148 non-null  object
#  33  Novedad            24 non-null     object
#  34  Entregado          54636 non-null  object
#  35  Anotación          335 non-null    object
#  36  Transportista      55148 non-null  object
#  37  Tipo Docu          55275 non-null  str
#  38  Nro visita         55275 non-null  int64
#  39  Estado.1           54992 non-null  object
# dtypes: float64(2), int64(9), object(11), str(18)
# memory usage: 16.9+ MB

# %%
df.drop(["Despacho", "Cod. trans", "Código", "Identificación", "Nombres", "Fecha pedido", 
         "Fecha facturado", "Hora facturado", "Fecha embalado", "Hora embalado", "Fecha despachado", "Estado",
         "Cajas", "Corte", "Placa vehiculo", "Regional", "Line pick", "Fecha masivo", "Latitud", "Longitud", "Track",
         "Novedad", "Entregado", "Anotación", "Transportista", "Tipo Docu", "Nro visita"], axis=1, inplace=True)

# %%
if 'Estado.1' in df.columns:
    df.rename(columns={'Estado.1':'Estado'}, inplace=True)

# %%
df.to_csv("cleaned_data.csv", index=False)
